# %% [markdown]
# <a href="https://www.kaggle.com/code/mahmmoudsalah/ddi-drugsafe-output?scriptVersionId=210886684" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !git clone --branch main https://github.com/OmarKhalifaa/GNN_DDI.git
# Out:
# Cloning into 'GNN_DDI'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 97 (delta 35), reused 80 (delta 24), pack-reused 2 (from 1)
# Receiving objects: 100% (97/97), 43.61 MiB | 23.60 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd /kaggle/working/GNN_DDI
# Out:
# /kaggle/working/GNN_DDI

# %%
# !python prepare.py
# Out:
# Tables :  [('event_number',), ('event',), ('drug',), ('extraction',)]
# drug :  [('index',), ('id',), ('target',), ('enzyme',), ('pathway',), ('smile',), ('name',)]
# event :  [('index',), ('id1',), ('name1',), ('id2',), ('name2',), ('interaction',)]
# event row COUNT:  [(37264,)]
# 0    P14780|Q00653|P01375|P01579|P33673
# 1                                Q02641
# Name: target, dtype: object
#    index  ...          name
# 0      0  ...   Glucosamine
# 1      1  ...  Azelnidipine
#
# [2 rows x 7 columns]
# /kaggle/working/GNN_DDI/prepare.py:53: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 954 bytes | 954.00 KiB/s, done.
# From https://github.com/OmarKhalifaa/GNN_DDI
#  * branch            main       -> FETCH_HEAD
#    57fa4cb..7ef1b50  main       -> origin/main
# Updating 57fa4cb..7ef1b50
# Fast-forward
#  concat.py | 8 ++++----
#  1 file changed, 4 insertions(+), 4 deletions(-)

# %%
# !python "/kaggle/working/GNN_DDI/GNN/main.py" --input "/kaggle/working/GNN_DDI/DDI/data5" --features "/kaggle/working/GNN_DDI/DDI/data5/featuers_m1.txt" --epoch 1 --dimensions 32
# Out:
# Namespace(input='/kaggle/working/GNN_DDI/DDI/data5', features='/kaggle/working/GNN_DDI/DDI/data5/featuers_m1.txt', walk_file=None, epoch=1, batch_size=64, eval_type='all', schema=None, dimensions=32, edge_dim=10, att_dim=20, walk_length=10, num_walks=20, window_size=5, negative_samples=5, neighbor_samples=10, patience=5, num_workers=16, file=None)
# We are loading data from: /kaggle/working/GNN_DDI/DDI/data5/train.txt
# Total training nodes: 570
# We are loading data from: /kaggle/working/GNN_DDI/DDI/data5/valid.txt
# We are loading data from: /kaggle/working/GNN_DDI/DDI/data5/test.txt
# Generating random walks for layer 0
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 7940it [00:00, 107353.50it/s]
# Generating random walks for layer 1
# 8980it [00:00, 56629.93it/s]
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 949 bytes | 949.00 KiB/s, done.
# From https://github.com/OmarKhalifaa/GNN_DDI
#  * branch            main       -> FETCH_HEAD
#    8610fc8..16bba1c  main       -> origin/main
# Updating 8610fc8..16bba1c
# Fast-forward
#  concat.py | 5 ++---
#  1 file changed, 2 insertions(+), 3 deletions(-)

# %%
# !python concat.py
# Out:
# /kaggle/working/GNN_DDI/DDI/data5/final_modelss1.csv shape after processing: (37050, 34)
# /kaggle/working/GNN_DDI/DDI/data5/final_modelss2.csv shape after processing: (37050, 34)
# /kaggle/working/GNN_DDI/DDI/data5/final_modelss3.csv shape after processing: (37050, 34)
# /kaggle/working/GNN_DDI/DDI/data5/final_modelss4.csv shape after processing: (37050, 34)
# Reduced data 1 length: 570
# Reduced data 2 length: 570
# Reduced data 3 length: 570
# Reduced data 4 length: 570
# Length of xs1: 570
# Number of feature dictionaries: 4
# First 5 keys in xs1: [0, 1, 2, 3, 4]
# full_pos shape: (37264, 3)
# DDI shape: (37264, 2)
# Multiplying indices 541 and 351: [0.02656227 0.02790939 0.02288867 0.02503109 0.02487968 0.02385757
#  0.02426968 0.03031032 0.02626601 0.02548944 0.02430399 0.03041907
#  0.0210613  0.01759591 0.02716357 0.0269257  0.02123744 0.02493482
#  0.02905957 0.02325038 0.02991576 0.0243281  0.02095308 0.02011403
# ...

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# Unpacking objects: 100% (3/3), 1.64 KiB | 1.64 MiB/s, done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# From https://github.com/OmarKhalifaa/GNN_DDI
#  * branch            main       -> FETCH_HEAD
#    65c6ae1..b3199de  main       -> origin/main
# Updating 65c6ae1..b3199de
# Fast-forward
#  train.py | 57 ++++++++++++++++++++++++++++++++++++++++++++++++++++++---
#  1 file changed, 54 insertions(+), 3 deletions(-)

# %%
# !python train.py
# Out:
# Loaded full_pos2.txt with shape: (37264, 3)
# new_label: 37264, first label: 1
# Cross-Validation Fold 1/5
# Processing Feature 1/4: 1
# Loaded features from /kaggle/working/GNN_DDI/DDI/data5/t_c_m_1_32.txt: (37264, 32)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733179919.246750   16656 service.cc:145] XLA service 0x7c4140004f10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733179919.246798   16656 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733179919.246803   16656 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1733179922.554042   16656 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Processing Feature 2/4: 2
# Loaded features from /kaggle/working/GNN_DDI/DDI/data5/t_c_m_2_32.txt: (37264, 32)
# ...
